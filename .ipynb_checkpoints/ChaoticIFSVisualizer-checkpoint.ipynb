# %% [markdown]
# # Visualization script
# - Code By Michael Sherif Naguib
# - license: MIT open source
# - Date: 3/14/19
# - @University of Tulsa
# - Description: the Chaotic IFS fractal code was adapted with datashader: Benifits: larger point plotting capability and faster navigation of said points (zoom + pan) Disadvantages: Points are pixles instead of dots so more points are required compared to matplotlib

# %%
#imports
from IteratedFunctionSystem import IFS
from ChaoticIFSBuilder import ChaoticIFSBuilder
from constants import constants
import numpy as np, pandas as pd, datashader as ds
from datashader import transfer_functions as tf
from datashader.colors import inferno, viridis
from numba import jit
import numpy.random
from colorcet import palette
import math
from decimal import *
import bokeh.plotting as bp
from datashader.bokeh_ext import InteractiveImage
import tqdm
from PlottingUtil import PlottingUtil

# %%
#a gui for asking the user for function settings: asks the user for settings 
newSystem = ChaoticIFSBuilder(constants,"goldendragon")
settings = newSystem.run()
function_set = settings[0]
points_quantity = settings[1]
speedup_mode = settings[2]

#Setup the IFS (SPEEDUP does not take into account theta and instead asks theta to be calculated into the stretch matrix beforehand)
if(speedup_mode):
    func = IFS.chaoticQuickAffineGenerator(function_set)
else:
    func = IFS.chaoticAffineGenerator(function_set)
    
#Preform the IFS calculations...
point_data = IFS.run(func,max_points=points_quantity)

#add to the points by clustering points around eachother by some differntial
additional_point_data = [[],[]]
delta=0.00001
for i in range(0,len(point_data)):
    x1 = point_data[0][i] +delta
    x2 = x1 -2*delta
    y1 = point_data[1][i] +delta
    y2 = y1 - 2*delta
    additional_point_data[0].append(x1)
    additional_point_data[0].append(x2)
    additional_point_data[0].append(x1)
    additional_point_data[0].append(x2)
    additional_point_data[1].append(y1)
    additional_point_data[1].append(y2)
    additional_point_data[1].append(y2)
    additional_point_data[1].append(y1)
n_point_data=[[],[]]
n_point_data[0] = list(point_data[0]) + list(additional_point_data[0])
n_point_data[1] = list(point_data[1]) + list(additional_point_data[1])

#Use the plotting Util to plot the data
pu = PlottingUtil(n_point_data)
pu.interactive_plot()
# Out:
# ---------------------------------------------------------------------
# Welcome To Chaotic IFS Fractal Generator by Michael Naguib 12/23/18
# ---------------------------------------------------------------------
#      Enable Speedup mode (rotation matrix not used): [y/n] y
# ---------------------------------------------------------------------
#      The available constant sets are:
#
#      bfern      rose      koch      natgalaxy      triangle      goldendragon
#      btree      branch      penta      spentagon      scarpet
#      pythagorean      sfcurve      durer      antisnow
#
#      (note if using quickAffine some may not work)
#      The default selected set is goldendragon
#
#   Use default set (d), create a new set (c), or select from the above (s): [d/c/s]d
# -------------------------- Selected Set -----------------------------
# [[array([[ 0.62367, -0.40337],
#        [ 0.40337,  0.62367]]),
#   array([0, 0]),
#   0,
#   0.5],
#  [array([[-0.37633, -0.40337],
#        [ 0.40337, -0.37633]]),
#   array([0.5, 0. ]),
#   0,
#   0.5]]
# ---------------------------------------------------------------------
#     Point Quantity (recomended 50000):1000000
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1000000/1000000 [00:47<00:00, 21192.38it/s]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1197">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="94a852a5-2b19-4b75-86f0-b85d1c8fb019" data-root-id="1198"></div>
#
# <script type="text/javascript">
#   (function(root) {
#   function embed_document(root) {
#
#   var docs_json = {"d34fb60b-b660-4b76-87c4-28cdc40ff2bb":{"roots":{"references":[{"attributes":{"background_fill_color":{"value":"black"},"below":[{"id":"1207","type":"LinearAxis"}],"left":[{"id":"1212","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"1207","type":"LinearAxis"},{"id":"1211","type":"Grid"},{"id":"1212","type":"LinearAxis"},{"id":"1216","type":"Grid"},{"id":"1228","type":"GlyphRenderer"}],"title":{"id":"1231","type":"Title"},"toolbar":{"id":"1220","type":"Toolbar"},"x_range":{"id":"1199","type":"Range1d"},"x_scale":{"id":"1203","type":"LinearScale"},"y_range":{"id":"1201","type":"Range1d"},"y_scale":{"id":"1205","type":"LinearScale"}},"id":"1198","subtype":"Figure","type":"Plot"},{"attributes":{"callback":{"id":"1230","type":"CustomJS"},"end":5,"start":-5},"id":"1199","type":"Range1d"},{"attributes":{},"id":"1203","type":"LinearScale"},{"attributes":{},"id":"1238","type":"Selection"},{"attributes":{},"id":"1213","type":"BasicTicker"},{"attributes":{},"id":"1237","type":"UnionRenderers"},{"attributes":{},"id":"1217","type":"PanTool"},{"attributes":{},"id":"1236","type":"BasicTickFormatter"},{"attributes":{"callback":{"id":"1230","type":"CustomJS"},"end":5,"start":-5},"id":"1201","type":"Range1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1217","type":"PanTool"},{"id":"1218","type":"WheelZoomTool"},{"id":"1219","type":"ResetTool"}]},"id":"1220","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"1231","type":"Title"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1227","type":"ImageRGBA"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1226","type":"ImageRGBA"},{"attributes":{},"id":"1219","type":"ResetTool"},{"attributes":{"args":{"x_range":{"id":"1199","type":"Range1d"},"y_range":{"id":"1201","type":"Range1d"}},"code":"\n        // Define a callback to capture errors on the Python side\n        function callback(msg){\n          if (msg.msg_type == \"execute_result\") {\n            if (msg.content.data['text/plain'] === \"'Complete'\") {\n               if (Bokeh._queued.length) {\n                   update_plot();\n               } else {\n                   Bokeh._blocked = false;\n               }\n               Bokeh._timeout = Date.now();\n            }\n          } else {\n            console.log(\"Python callback returned unexpected message:\", msg)\n          }\n        }\n        callbacks = {iopub: {output: callback}};\n\n        function update_plot() {\n            range = Bokeh._queued;\n            var cmd = \"from datashader.bokeh_ext import InteractiveImage; InteractiveImage._callbacks['c3ffce55-b0e2-4737-abdd-ff26a5afa2b9'].update(\" + range + \")\"\n            // Execute the command on the Python kernel\n            if (IPython.notebook.kernel !== undefined) {\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(cmd, callbacks, {silent : false});\n            }\n            Bokeh._queued = [];\n        }\n\n        var plot = x_range.plots[0];\n        // Generate a command to execute in Python\n        var ranges = {xmin: x_range.start,\n                       ymin: y_range.start,\n                       xmax: x_range.end,\n                       ymax: y_range.end,\n                       w: Math.floor(plot.width),\n                       h: Math.floor(plot.height)}\n        var range_str = JSON.stringify(ranges)\n\n        if (!Bokeh._queued) {\n            Bokeh._queued = [];\n            Bokeh._blocked = false;\n            Bokeh._timeout = Date.now();\n        }\n\n        timeout = Bokeh._timeout + 2000;\n        if (typeof _ === \"undefined\") {\n        } else if ((Bokeh._blocked && (Date.now() < timeout)))  ...
#   var render_items = [{"docid":"d34fb60b-b660-4b76-87c4-28cdc40ff2bb","notebook_comms_target":"c3ffce55-b0e2-4737-abdd-ff26a5afa2b9","roots":{"1198":"94a852a5-2b19-4b75-86f0-b85d1c8fb019"}}];
#   root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#
#   }
#   if (root.Bokeh !== undefined) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined) {
#         embed_document(root);
#         clearInterval(timer);
#       }
#       attempts++;
#       if (attempts > 100) {
#         console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         clearInterval(timer);
#       }
#     }, 10, root)
#   }
# })(window);
# </script>
